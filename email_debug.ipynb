# %%
import { emailNotificationService } from '../services/emailNotificationService';

// ... logic to simulate calling the function
// await emailNotificationService.sendManualQuoteEmail(quote, recipient);
